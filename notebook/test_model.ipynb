# %%
import sys
from pathlib import Path

# Make project root importable when notebook is opened from notebook/
PROJECT_ROOT = (
    Path.cwd().resolve().parent if Path.cwd().name == "notebook" else Path.cwd().resolve()
)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.mlp.model import SequentialNeuralNetwork
